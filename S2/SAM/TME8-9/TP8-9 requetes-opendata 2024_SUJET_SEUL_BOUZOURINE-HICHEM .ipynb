# %% [markdown]
# # SAM 2024 : TP Requêtes multi-sources pour l'open data
#
# Séances 8 et 9
#
# date du document : 28/03/2024
#
#
# ## BOUZOURINE Hichem - 21319982
#
# Objectif : Comprendre et réaliser des jointures entre deux sources réelles distantes lorsque l'accès aux sources est conforme aux standards de l'*open data*.
#
# Contexte : On considère deux sources réelles ainsi que des exemples de requêtes pouvant être posées sur chacune d'entre elles.
#
# On vous demande de mettre en oeuvre des scénarios de requêtes **MULTI** sources.
#
# Pour 2024 : Faire l'exercice 3 en priorité

# %% [markdown]
# ## Préparation
#
# **Copier** ce notebook dans votre drive et l'exécuter dans l'environnement colab de google

# %%
# !pip install SPARQLWrapper
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: SPARQLWrapper in /home/hichem/.local/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in /home/hichem/.local/lib/python3.10/site-packages (from SPARQLWrapper) (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/hichem/.local/lib/python3.10/site-packages (from rdflib>=6.1.1->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/lib/python3/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (2.4.7)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)

# %% [markdown]
# ### Manipuler le résultat d'une requête
# Fonctions **tableauResultat** pour extraire  le résultat d'une requête

# %%
import pandas as pd

#pd.set_option('max_columns', None)
pd.set_option('max_colwidth', None)

# Déterminer la liste des noms d'attributs du résultat, en tenant compte des attributs optionnels.
def schemaResultat(resultats, limit=100):
  d = {}
  for elt in resultats[:limit]:
    for (pos, nom) in enumerate(elt):
      sum_pos, nb = d.get(nom, (0, 0))
      d[nom] = (sum_pos + pos, nb + 1)
  mean_pos_by_name = [(sum_pos / nb, nom) for (nom, (sum_pos, nb)) in d.items()]
  colonnes = [nom for (mean_pos, nom) in sorted(mean_pos_by_name)]
  return colonnes

def tableauResultat(resultats, limit=100, colonnes=None):
  if colonnes is None :
    colonnes = schemaResultat(resultats, limit)
  tableau = []
  for elt in resultats[:limit]:
    row = {name:v.value for name, v in elt.items()}
    tableau.append([row.get(n, "") for n in colonnes])
  return tableau

print ("fonctions définies")
# Out:
# fonctions définies

# %% [markdown]
# Afficher le résultat

# %%
def afficherResultat(resultats, limit=100):
  print(len(resultats), "éléments")
  colonnes = schemaResultat(resultats, limit)
  print("schéma: ", colonnes)
  result = tableauResultat(resultats, limit, colonnes)
  return pd.DataFrame(result, columns = colonnes)

print ("fonctions définies")
# Out:
# fonctions définies

# %% [markdown]
# ### Importer le pilote pour accéder aux sources

# %%
from SPARQLWrapper import SPARQLWrapper2
print("pilote importé")
# Out:
# pilote importé

# %% [markdown]
# ### Préparer l'accès à la source BNF

# %%
# Connexion à la BNF
BNF = SPARQLWrapper2("http://data.bnf.fr/sparql")

BNF_prefix = """
PREFIX dc: <http://purl.org/dc/terms/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX rda: <http://rdaregistry.info/Elements/w/#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

PREFIX bnf: <http://data.bnf.fr/ontology/bnf-onto/>

PREFIX bio: <http://vocab.org/bio/0.1/>
PREFIX voc2: <http://rdvocab.info/ElementsGr2/>
"""
print(BNF_prefix)
# Out:
# PREFIX dc: <http://purl.org/dc/terms/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX rda: <http://rdaregistry.info/Elements/w/#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# PREFIX bnf: <http://data.bnf.fr/ontology/bnf-onto/>
#
# PREFIX bio: <http://vocab.org/bio/0.1/>
# PREFIX voc2: <http://rdvocab.info/ElementsGr2/>

# %% [markdown]
# ### Préparer l'accès à la source DBPEDIA

# %%
# Connexion à DBPEDIA France.
DBPEDIA = SPARQLWrapper2("http://fr.dbpedia.org/sparql")

DBPEDIA_prefix =  """
PREFIX dc:   <http://purl.org/dc/terms/>
PREFIX xsd:  <http://www.w3.org/2001/XMLSchema#>

PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX rdf:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

PREFIX dbo:  <http://dbpedia.org/ontology/>

# Dans cette source, les noms de propriétés sont en français
PREFIX dbp:  <http://fr.dbpedia.org/property/>
"""
# print(DBPEDIA_prefix)

# %% [markdown]
# ## Source 1 : La bibliothèque BNF

# %% [markdown]
# ### BNF P1: Le nom des personnes
# On suppose les relations :
# *    **CrééPar**(ouvrage, auteur)
# *    **Nom**(auteur, nom)
#
# En SQL, la requête s'exprimerait ainsi:
#
# > select distinct n.nom
#
# > from CrééPar c, Nom n
#
# > where c.auteur = n.auteur

# %%
requete = BNF_prefix + """
SELECT distinct ?nom
WHERE {
  # ?ouvrage dc:creator ?auteur .       # un ouvrage est créé par au moins un auteur
  # ?auteur foaf:name ?nom              # un auteur a un nom
}
LIMIT 5
"""

BNF.setQuery(requete)
resultats = BNF.query().bindings
for r in tableauResultat(resultats):
  print(r)
# Out:
# ['Ahmed Ben Brihmat']
# ['Constantin Roussel']
# ['François-Marie-Stéphane Guillot']
# ['Paul Émilien Félix Defontaine']
# ['François Joseph Ferdinand Marchal']

# %% [markdown]
# ### BNF T1: liste de thèmes
# #### Les *themes* des oeuvres dont l'auteur est référencé dans dbpedia france
#
# En SQL, cette requête pourrait s'exprimer sur les tables suivantes
#
# **créé_par** (livre, auteur)
#
# **type_d_expression** (livre, type_expre)  -- exple de tpye d'expression: textuelle
#
# **écrit_en** (livre, langue)
#
# **sujet** (livre, thème)
#
# **auteur_équivalent** (auteur, auteur_source2)
#
# et une condition SQL serait : WHERE auteur_source2 like 'http://fr.dbpedia.org%'

# %%
requete = BNF_prefix + """
SELECT distinct ?theme
WHERE {# A compléter


  # une oeuvre est associée a (au moins) un auteur
  # ?livre dc:creator ?auteur .

  # un livre est un ouvrage dont la forme d'expression est textuelle (te)
  # ?livre rda:P10004 <http://data.bnf.fr/vocabulary/work-form/te> .

  # livre écrit en langue française
  # ?livre dc:language <http://id.loc.gov/vocabulary/iso639-2/fre> .

  # le livre a au moins un theme
  # ?livre bnf:subject ?theme.

  # l'auteur existe également dans une autre source,
  # on dit qu'il est "aligné" avec un autre instance du même individu.
  # ?auteur owl:sameAs ?auteurDbpedia .

  # la référence externe "pointe" vers dbpedia
  FILTER ( regex(?auteurDbpedia, "http://fr.dbpedia.org")  )

}
ORDER BY ?theme
LIMIT 20
"""

BNF.setQuery(requete)
resultats = BNF.query().bindings
afficherResultat(resultats)

# Exemple:
# Informatique
# Langues
# Philosophie
# Out:
# 20 éléments
# schéma:  ['theme']
#                                           theme
# 0                       Administration publique
# 1                     Anthropologie. Ethnologie
# 2                                  Architecture
# 3   Archéologie. Préhistoire. Histoire ancienne
# 4                                           Art
# 5                     Art et science militaires
# 6                             Arts du spectacle
# 7                               Arts graphiques
# 8                                    Astronomie
# 9                                   Audiovisuel
# 10                                     Biologie
# 11                                    Botanique
# 12                                       Chimie
# 13                      Dessin. Arts décoratifs
# 14                                        Droit
# 15                                   Ethnonymes
# 16                                   Géographie
# 17                       Géographie de l'Europe
# 18                      Géographie de la France
# 19                 Géographie du reste du monde

# %% [markdown]
# ###  BNF A1 : une liste d'auteurs
#
# A1 : Liste des auteurs de livres écrits en français et nés pendant une certaine période, par exemple au 20eme siècle. Afficher le nom de l'auteur, son année et lieu de naissance.

# %%
requete = BNF_prefix + """
SELECT distinct ?nom  ?naissance ?lieu
WHERE {

# une oeuvre est associée a (au moins) un auteur
# ?livre dc:creator ?auteur.

# livre écrit en français
# ?livre dc:language <http://id.loc.gov/vocabulary/iso639-2/fre> .

# un auteur a un nom
# ?auteur foaf:name ?nom .

# un auteur a une année et un lieu de naissance
# ?auteur bio:birth ?naissance.
# ?auteur voc2:placeOfBirth ?lieu

# on sélectionne les années de naissance dans l'intervalle [1900, 2000]
FILTER (xsd:integer (?naissance) > '1900'^^xsd:integer
     && xsd:integer (?naissance) < '2000'^^xsd:integer )
}
#ORDER BY ?nom
LIMIT 20
"""

BNF.setQuery(requete)
resultats = BNF.query().bindings
afficherResultat(resultats)
# Out:
# 20 éléments
# schéma:  ['nom', 'naissance', 'lieu']
#                           nom naissance  \
# 0              Alex Pol Axely      1920
# 1            Alexandra Pecker      1906
# 2   Marie-Françoise Christout      1928
# 3              Gabriel Cousin      1918
# 4                Éric Muraise      1908
# 5                  Marc Peyre      1904
# 6               Jean Savatier      1922
# 7      Hans Ludwig Cohn Jaffé      1915
# 8                   Jean Canu      1910
# 9                 Albert Ayme      1920
# 10               Pierre Bovet      1946
# 11                Jim Alcheik      1931
# 12           Raymond Lepoutre      1922
# 13                Jacob Rabin      1912
# 14              Louis Parrens      1904
# 15    Jacqueline Karageorghis      1932
# 16                Pascal Kern      1952
# 17                Henri Frère      1908
# 18     Alain Hervé du Penhoat      1930
# 19                 Jean Brian      1911
#
#                                                lieu
# 0                       Chaillé-les-Marais (Vendée)
# 1                                             Paris
# 2                                 Neuilly-sur-Seine
# 3                              Droué (Loir et Cher)
# 4                               Châteauroux (Indre)
# 5                                         Marseille
# 6                                  Poitiers (Vienne
# 7                  Francfort-sur-le-Main, Allemagne
# 8                               Tourlaville, Manche
# 9                             Montpellier (Hérault)
# 10                                Lausanne (Suisse)
# 11                                Duperré (Algérie)
# 12                                        Bruxelles
# 13     Petaḥ-Tiqva (Palestine, aujourd'hui Israël)
# 14                                            Paris
# 15                            Saint-Étienne (Loire)
# 16                                            Paris
# 17  Saint-Génis-des-Fontaines (Pyrénées-Orientales)
# 18                               Cléder (Finistère)
# 19                            Embrun (Hautes-Alpes)

# %% [markdown]
# ###  BNF A2 : les auteurs de la BNF référencés dans dbpedia
# Les auteurs ayant un identifiant externe pointant vers dbpedia

# %%
requete = BNF_prefix + """
SELECT distinct ?nom  ?naissance ?auteurDbpedia
WHERE {

# une oeuvre est associée a (au moins) un auteur
# ?livre dc:creator ?auteur.

# livre écrit en français
# ?livre dc:language <http://id.loc.gov/vocabulary/iso639-2/fre> .

# un auteur a un nom, et une année de naissance
# ?auteur foaf:name ?nom ; bio:birth ?naissance .

# l'auteur existe également dans une source externe,
# on dit qu'il est "aligné" avec un autre instance du même individu.
# ?auteur owl:sameAs ?auteurDbpedia .

# naissance dans l'intervalle [1900, 2000] et la référence externe "pointe" vers dbpedia
FILTER (xsd:integer (?naissance) > '1900'^^xsd:integer
     && xsd:integer (?naissance) < '2000'^^xsd:integer
     && regex(?auteurDbpedia, "http://fr.dbpedia.org")
     )
}
ORDER BY desc(?naissance)
LIMIT 10
"""

BNF.setQuery(requete)

resultats = BNF.query().bindings
afficherResultat(resultats)
# Out:
# 10 éléments
# schéma:  ['nom', 'naissance', 'auteurDbpedia']
#                        nom naissance  \
# 0          Vickie Gendreau      1989
# 1              Axl Cendres      1982
# 2        Geneviève Castrée      1981
# 3          Isabelle Périer      1978
# 4  Nathanaël Dupré La Tour      1977
# 5          Coralie Delaume      1976
# 6         Claire Guézengar      1972
# 7          Philippe Nassif      1971
# 8           Benoït Violier      1971
# 9              Fatou Cissé      1971
#
#                                                       auteurDbpedia
# 0                    http://fr.dbpedia.org/resource/Vickie_Gendreau
# 1                        http://fr.dbpedia.org/resource/Axl_Cendres
# 2        http://fr.dbpedia.org/resource/Genevi%C3%A8ve_Castr%C3%A9e
# 3               http://fr.dbpedia.org/resource/Isabelle_P%C3%A9rier
# 4  http://fr.dbpedia.org/resource/Nathana%C3%ABl_Dupr%C3%A9_La_Tour
# 5                    http://fr.dbpedia.org/resource/Coralie_Delaume
# 6                   http://fr.dbpedia.org/resource/Claire_Guezengar
# 7                    http://fr.dbpedia.org/resource/Philippe_Nassif
# 8                http://fr.dbpedia.org/resource/Beno%C3%AEt_Violier
# 9             http://fr.dbpedia.org/resource/Fatou_Fanny-Ciss%C3%A9

# %% [markdown]
# ### BNF A3 : Les auteurs d'une oeuvre philosophique
#
# Voir T1 pour la liste des thèmes possibles autres que la philosophie.
#
# On se limite aux oeuvres écrite en français et sont l'auteur est référencé dans dbpedia france.

# %%
requete = BNF_prefix + """
SELECT distinct ?nom ?auteurDbpedia ?type_ouvrage
WHERE {

  # ?livre dc:creator ?auteur .

  # un livre est un ouvrage textuel
  # (revoir la formulation de ce triplet...)
  # ?livre rda:P10004 <http://data.bnf.fr/vocabulary/work-form/te> .

  # le livre existe également dans une autre source
  # ?livre owl:sameAs ?livreWiki .

  # livre écrit en français
  # ?livre dc:language <http://id.loc.gov/vocabulary/iso639-2/fre> .

  # le livre a pour theme "Philosophie"
  # ?livre bnf:subject "Philosophie" .

  # le nom de l'auteur
  # ?auteur foaf:name ?nom .

  # l'auteur existe également dans une autre source
  # ?auteur owl:sameAs ?auteurDbpedia .

  FILTER ( regex(?livreWiki, "http://wikidata.org")
       &&  regex(?auteurDbpedia, "http://fr.dbpedia.org")
  )
}
ORDER BY ?auteurDbpedia

LIMIT 20
"""

BNF.setQuery(requete)
resultats =  BNF.query().bindings
afficherResultat(resultats, 5)
# Out:
# 20 éléments
# schéma:  ['nom', 'auteurDbpedia']
#                      nom  \
# 0          Alexis Carrel
# 1     Antoine de Rivarol
# 2     Bernard-Henri Lévy
# 3  Bernard de Fontenelle
# 4         Claude Guillon
#
#                                                        auteurDbpedia
# 0                       http://fr.dbpedia.org/resource/Alexis_Carrel
# 1                  http://fr.dbpedia.org/resource/Antoine_de_Rivarol
# 2             http://fr.dbpedia.org/resource/Bernard-Henri_L%C3%A9vy
# 3     http://fr.dbpedia.org/resource/Bernard_Le_Bouyer_de_Fontenelle
# 4  http://fr.dbpedia.org/resource/Claude_Guillon_%28%C3%A9crivain%29

# %% [markdown]
# ###  BNF L1 : Les livres avec leurs auteurs
#
# Les livres écrit en français au 21eme siècle,  référencés dans wikidata et dont l'auteur est référencé dans dbpedia

# %%
requete = BNF_prefix + """
SELECT distinct ?annee ?nom ?titre ?auteurDbpedia
WHERE {

  # ?livre dc:creator ?auteur .

  # l'année de parution du livre
  # ?livre dc:date ?annee .

  # le titre du livre
  # ?livre dc:title ?titre .

  # un livre est un ouvrage textuel
  # ?livre rda:P10004 <http://data.bnf.fr/vocabulary/work-form/te> .

  # le livre existe également dans une autre source
  # ?livre owl:sameAs ?livreWiki .

  # livre écrit en français
  # ?livre dc:language <http://id.loc.gov/vocabulary/iso639-2/fre> .

  # le nom de l'auteur
  # ?auteur foaf:name ?nom.

  # l'auteur existe également dans une autre source
  # ?auteur owl:sameAs ?auteurDbpedia .

  FILTER (
       xsd:integer (?annee) > '2000'^^xsd:integer
    && xsd:integer (?annee) < '2099'^^xsd:integer
    && regex(?livreWiki, "http://wikidata.org")
    &&  regex(?auteurDbpedia, "http://fr.dbpedia.org")
  )
}
#ORDER BY desc(?annee)

LIMIT 20
"""

BNF.setQuery(requete)
resultats =  BNF.query().bindings
afficherResultat(resultats)
# Out:
# 20 éléments
# schéma:  ['annee', 'nom', 'titre', 'auteurDbpedia']
#    annee                       nom  \
# 0   2006          Jonathan Littell
# 1   2001              Claude Simon
# 2   2002                André Gide
# 3   2001             Yves Bonnefoy
# 4   2003        J. M. G. Le Clézio
# 5   2001          Catherine Millet
# 6   2001        Michel Houellebecq
# 7   2005             Michel Onfray
# 8   2006           Pascal Quignard
# 9   2007          Nathacha Appanah
# 10  2010              Jean Echenoz
# 11  2012           Waǧdī Muʿawwaḍ
# 12  2014             Édouard Louis
# 13  2007  Comité invisible. France
# 14  2008              Jean Echenoz
# 15  2018          Peter Gelderloos
# 16  2004             Alain Damasio
# 17  2013            Thomas Piketty
# 18  2010             Michel Onfray
# 19  2015        Michel Houellebecq
#
#                                                                                        titre  \
# 0                                                                         Les Bienveillantes
# 1                                                                                 Le tramway
# 2                                                                                  Le ramier
# 3                                                                       Les planches courbes
# 4                                                                                Révolutions
# 5                                                            La vie sexuelle de Catherine M.
# 6                                                                                 Plateforme
# 7                                                                        Traité d'athéologie
# 8                                                                               Villa Amalia
# 9                                                                           Le dernier frère
# 10                                                                               Des éclairs
# 11                                                                                     Anima
# 12                                                            En finir avec Eddy Bellegueule
# 13                                                                  L'insurrection qui vient
# 14                                                                                    Courir
# 15  Comment la non-violence protège l'État : essai sur l'inefficacité des mouvements sociaux
# 16                                                                    La horde du contrevent
# 17                                                                 Le capital au XXIe siècle
# 18                                                                 Le crépuscule d'une idole
# 19                                                                                Soumission
#
#                                              auteurDbpedia
# 0          http://fr.dbpedia.org/resource/Jonathan_Littell
# 1              http://fr.dbpedia.org/resource/Claude_Simon
# 2           http://fr.dbpedia.org/resource/Andr%C3%A9_Gide
# 3             http://fr.dbpedia.org/resource/Yves_Bonnefoy
# 4   http://fr.dbpedia.org/resource/J._M._G._Le_Cl%C3%A9zio
# 5          http://fr.dbpedia.org/resource/Catherine_Millet
# 6        http://fr.dbpedia.org/resource/Michel_Houellebecq
# 7             http://fr.dbpedia.org/resource/Michel_Onfray
# 8           http://fr.dbpedia.org/resource/Pascal_Quignard
# 9          http://fr.dbpedia.org/resource/Nathacha_Appanah
# 10             http://fr.dbpedia.org/resource/Jean_Echenoz
# 11            http://fr.dbpedia.org/resource/Wajdi_Mouawad
# 12       http://fr.dbpedia.org/resource/%C3%89douard_Louis
# 13    http://fr.dbpedia.org/resource/Comit%C3%A9_invisible
# 14             http://fr.dbpedia.org/resource/Jean_Echenoz
# 15         http://fr.dbpedia.org/resource/Peter_Gelderloos
# 16            http://fr.dbpedia.org/resource/Alain_Damasio
# 17           http://fr.dbpedia.org/resource/Thomas_Piketty
# 18            http://fr.dbpedia.org/resource/Michel_Onfray
# 19       http://fr.dbpedia.org/resource/Michel_Houellebecq

# %% [markdown]
# ## Source 2 : DBPedia France

# %% [markdown]
# ### D1 : Informations sur une personne dont le nom contient certains mots.
# Afficher le nom, nationalité, profession, date et lieu de naissance

# %%
requete_parametree = DBPEDIA_prefix + """
  SELECT ?p ?name ?nationalité ?profession year(xsd:dateTime(?naissance)) as ?naissance  ?lieu
  WHERE {
    # ?p a dbo:Person .
    # ?p foaf:name ?name .
    # ?p dbo:birthDate ?naissance
    optional {?p dbp:nationalité ?nationalité}
    optional {?p dbp:profession ?profession}
    optional {?p dbp:lieuDeNaissance ?lieu}

  FILTER (regex(?p, "{MOTIF}", "i") )
  }
  LIMIT 10
"""

# l'expression régulière du nom à retrouver
motif = "Victor.*Hug"

requete = requete_parametree.replace("{MOTIF}", motif)

DBPEDIA.setQuery(requete)
res = DBPEDIA.query().bindings
afficherResultat(res)
# Out:
# 10 éléments
# schéma:  ['p', 'name', 'nationalité', 'profession', 'naissance', 'lieu']
#                                                                 p  \
# 0  http://fr.dbpedia.org/resource/Victor_Hugo_de_Azevedo_Coutinho
# 1  http://fr.dbpedia.org/resource/Victor_Hugo_de_Azevedo_Coutinho
# 2  http://fr.dbpedia.org/resource/Victor_Hugo_de_Azevedo_Coutinho
# 3  http://fr.dbpedia.org/resource/Victor_Hugo_de_Azevedo_Coutinho
# 4  http://fr.dbpedia.org/resource/Victor_Hugo_de_Azevedo_Coutinho
# 5  http://fr.dbpedia.org/resource/Victor_Hugo_de_Azevedo_Coutinho
# 6  http://fr.dbpedia.org/resource/Victor_Hugo_de_Azevedo_Coutinho
# 7  http://fr.dbpedia.org/resource/Victor_Hugo_de_Azevedo_Coutinho
# 8                http://fr.dbpedia.org/resource/Victor_Hugo_Green
# 9                http://fr.dbpedia.org/resource/Victor_Hugo_Green
#
#                               name                              nationalité  \
# 0  Victor Hugo de Azevedo Coutinho  http://fr.dbpedia.org/resource/Portugal
# 1                                   http://fr.dbpedia.org/resource/Portugal
# 2                                   http://fr.dbpedia.org/resource/Portugal
# 3                                   http://fr.dbpedia.org/resource/Portugal
# 4  Victor Hugo de Azevedo Coutinho  http://fr.dbpedia.org/resource/Portugal
# 5  Victor Hugo de Azevedo Coutinho  http://fr.dbpedia.org/resource/Portugal
# 6                                   http://fr.dbpedia.org/resource/Portugal
# 7  Victor Hugo de Azevedo Coutinho  http://fr.dbpedia.org/resource/Portugal
# 8                Victor Hugo Green                                Américain
# 9                Victor Hugo Green                                Américain
#
#                                 profession naissance  \
# 0  http://fr.dbpedia.org/resource/Officier      1871
# 1  http://fr.dbpedia.org/resource/Officier      1871
# 2  http://fr.dbpedia.org/resource/Officier      1871
# 3  http://fr.dbpedia.org/resource/Officier      1871
# 4  http://fr.dbpedia.org/resource/Officier      1871
# 5  http://fr.dbpedia.org/resource/Officier      1871
# 6  http://fr.dbpedia.org/resource/Officier      1871
# 7  http://fr.dbpedia.org/resource/Officier      1871
# 8                                               1892
# 9                                               1892
#
#                                         lieu
# 0       http://fr.dbpedia.org/resource/Macao
# 1       http://fr.dbpedia.org/resource/Macao
# 2       http://fr.dbpedia.org/resource/Macao
# 3       http://fr.dbpedia.org/resource/Macao
# 4       http://fr.dbpedia.org/resource/Macao
# 5       http://fr.dbpedia.org/resource/Macao
# 6       http://fr.dbpedia.org/resource/Macao
# 7       http://fr.dbpedia.org/resource/Macao
# 8    http://fr.dbpedia.org/resource/New_York
# 9  http://fr.dbpedia.org/resource/États-Unis

# %% [markdown]
# ### D2 : les infos détaillées sur une certaine personne

# %%
requete_parametree = DBPEDIA_prefix + """
  SELECT distinct  ?name ?nationalite ?interet ?idee
  WHERE {
    # ?pers foaf:name ?name
    optional {?pers dbp:nationalité ?nationalite}
    optional {?pers dbo:mainInterest ?interet}
    optional {?pers dbp:idéesRemarquables ?idee}

    FILTER ( ?pers = <{PERSONNE}> && STRLEN(?name) != 0)
  }
  order by ?interet ?idee
  LIMIT 20
"""
# On fixe une certaine personne
personne = 'http://fr.dbpedia.org/resource/Simone_de_Beauvoir'
#personne = 'http://fr.dbpedia.org/resource/Jean-Paul_Sartre'

# fixer le nom de la personne dans la requête
requete = requete_parametree.replace("{PERSONNE}", personne)

# print("la requête est :", requete)

DBPEDIA.setQuery(requete)
res = DBPEDIA.query().bindings
afficherResultat(res)
# Out:
# 3 éléments
# schéma:  ['name', 'interet', 'idee']
#                  name                                     interet  \
# 0  Simone de Beauvoir  http://fr.dbpedia.org/resource/Philosophie
# 1  Simone de Beauvoir    http://fr.dbpedia.org/resource/Politique
# 2  Simone de Beauvoir      http://fr.dbpedia.org/resource/Éthique
#
#                                                                         idee
# 0  Éthiques du féminisme, féminisme existentialiste, éthiques de l'ambigüité
# 1  Éthiques du féminisme, féminisme existentialiste, éthiques de l'ambigüité
# 2  Éthiques du féminisme, féminisme existentialiste, éthiques de l'ambigüité

# %% [markdown]
# ### D3 : la liste des oeuvres principales d'une personne donnée

# %%
requete_parametree = DBPEDIA_prefix +  """
    SELECT distinct ?name ?oeuvre
    WHERE {
      # ?pers foaf:name ?name
      optional {?pers  dbp:œuvresPrincipales ?oeuvre}
    FILTER ( ?pers = <{PERSONNE}> && STRLEN(?name) != 0)
}
order by ?oeuvre
LIMIT 10
"""
# On fixe une certaine personne
personne = 'http://fr.dbpedia.org/resource/Simone_de_Beauvoir'

requete = requete_parametree.replace("{PERSONNE}", personne)

DBPEDIA.setQuery(requete)
res = DBPEDIA.query().bindings
afficherResultat(res)
# Out:
# 5 éléments
# schéma:  ['name', 'oeuvre']
#                  name                             oeuvre
# 0  Simone de Beauvoir                          L'Invitée
# 1  Simone de Beauvoir                  La Force de l'âge
# 2  Simone de Beauvoir                   Le Deuxième Sexe
# 3  Simone de Beauvoir                      Les Mandarins
# 4  Simone de Beauvoir  Mémoires d'une jeune fille rangée

# %% [markdown]
# ### D4 : les influenceurs d'une personne donnée

# %%
requete_parametree = DBPEDIA_prefix + """
   SELECT distinct ?name ?influenceur
    WHERE {
      # ?pers foaf:name ?name
      optional {?pers  dbo:influencedBy ?influenceur}

    FILTER ( ?pers = <{PERSONNE}> && STRLEN(?name) != 0)
}
order by ?influenceur
LIMIT 10
"""

# On fixe une certaine personne
PERSONNE = 'http://fr.dbpedia.org/resource/Simone_de_Beauvoir'
#PERSONNE = 'http://fr.dbpedia.org/resource/Judith_Butler'

# fixer le nom de la personne dans la requête
requete = requete_parametree.replace("{PERSONNE}", PERSONNE)

DBPEDIA.setQuery(requete)
res = DBPEDIA.query().bindings
print(len(res), 'resultats')
afficherResultat(res)
# Out:
# 10 resultats
# 10 éléments
# schéma:  ['name', 'influenceur']
#                  name  \
# 0  Simone de Beauvoir
# 1  Simone de Beauvoir
# 2  Simone de Beauvoir
# 3  Simone de Beauvoir
# 4  Simone de Beauvoir
# 5  Simone de Beauvoir
# 6  Simone de Beauvoir
# 7  Simone de Beauvoir
# 8  Simone de Beauvoir
# 9  Simone de Beauvoir
#
#                                                     influenceur
# 0                   http://fr.dbpedia.org/resource/Alfred_Adler
# 1                 http://fr.dbpedia.org/resource/Edmund_Husserl
# 2                  http://fr.dbpedia.org/resource/Emmanuel_Kant
# 3  http://fr.dbpedia.org/resource/François_Poullain_de_La_Barre
# 4               http://fr.dbpedia.org/resource/Friedrich_Engels
# 5            http://fr.dbpedia.org/resource/Friedrich_Nietzsche
# 6  http://fr.dbpedia.org/resource/Georg_Wilhelm_Friedrich_Hegel
# 7               http://fr.dbpedia.org/resource/Jean-Paul_Sartre
# 8                      http://fr.dbpedia.org/resource/Karl_Marx
# 9               http://fr.dbpedia.org/resource/Martin_Heidegger

# %% [markdown]
# ### D5 : Les auteurs nés en 2001
# Utiliser la fonction year pour extraire l'année de naissance à partir d'une date de naissance.

# %%
requete_parametree = DBPEDIA_prefix + """
    SELECT distinct ?p ?name year(xsd:dateTime(?naissance)) as ?naissance
    WHERE {
      # ?p a dbo:Person .
      # ?p foaf:name ?name .
      # ?p dbo:birthDate ?naissance
      FILTER( regex(?naissance, "{ANNEE}") && STRLEN(?name) != 0)
    }
    order by ?p
    LIMIT 10
"""

année = 2001
requete = requete_parametree.replace("{ANNEE}", str(année))

DBPEDIA.setQuery(requete)
res = DBPEDIA.query().bindings
afficherResultat(res)
# Out:
# 10 éléments
# schéma:  ['p', 'name', 'naissance']
#                                                        p  \
# 0           http://fr.dbpedia.org/resource/Abraham_Attah
# 1        http://fr.dbpedia.org/resource/Adam_Siao_Him_Fa
# 2           http://fr.dbpedia.org/resource/Adrien_Warion
# 3         http://fr.dbpedia.org/resource/Adèle_Castillon
# 4                http://fr.dbpedia.org/resource/Ai_Ogura
# 5           http://fr.dbpedia.org/resource/Aiko_de_Toshi
# 6     http://fr.dbpedia.org/resource/Aleksandr_Nikichine
# 7       http://fr.dbpedia.org/resource/Aleksandr_Smolyar
# 8      http://fr.dbpedia.org/resource/Aleksej_Pokuševski
# 9  http://fr.dbpedia.org/resource/Alessandro_Michieletto
#
#                      name naissance
# 0           Abraham Attah      2001
# 1        Adam Siao Him Fa      2001
# 2           Adrien Warion      2001
# 3         Adèle Castillon      2001
# 4                Ai Ogura      2001
# 5                    Aiko      2001
# 6     Aleksandr Nikichine      2001
# 7       Aleksandr Smolyar      2001
# 8      Aleksej Pokuševski      2001
# 9  Alessandro Michieletto      2001

# %% [markdown]
# ### D6 : La liste de tous les intérets principaux

# %%
requete = DBPEDIA_prefix + """
    SELECT distinct ?interet
    WHERE {
      # ?personne dbo:mainInterest ?o .
      # ?o rdfs:label ?interet .

      FILTER (langMatches( lang(?interet), "FR" ) )
}
order by ?interet
LIMIT 10
"""

DBPEDIA.setQuery(requete)
res = DBPEDIA.query().bindings
afficherResultat(res)
# Out:
# 10 éléments
# schéma:  ['interet']
#                        interet
# 0          Activisme politique
# 1                      Afrique
# 2                 Agnosticisme
# 3                     Alchimie
# 4                        Amour
# 5             Amour platonique
# 6                  Angélologie
# 7                Anthropologie
# 8   Anthropologie linguistique
# 9  Anthropologie philosophique

# %% [markdown]
# ### D7 la liste des philosophes dans Dbpedia

# %%
import time

requete = DBPEDIA_prefix + """

SELECT distinct  ?name ?p
WHERE {
  # ?p rdf:type dbo:Philosopher .
  # ?p foaf:name ?name
}
order by ?name
limit 10
"""

start_time = time.time()

DBPEDIA.setQuery(requete)
res = DBPEDIA.query().bindings

duree = int ( (time.time() - start_time) * 1000)
print(f"durée {duree} ms")

afficherResultat(res)
# Out:
# durée 80 ms
# 10 éléments
# schéma:  ['name', 'p']
#   name                                                            p
# 0       http://fr.dbpedia.org/resource/Œuvre_de_Friedrich_Nietzsche
# 1                http://fr.dbpedia.org/resource/Abu_'Ali_Al-Jubbâ'i
# 2                     http://fr.dbpedia.org/resource/Abu_al-Hudhayl
# 3              http://fr.dbpedia.org/resource/Abū_Hāshīm_al-Jubbā'ī
# 4                         http://fr.dbpedia.org/resource/Adam_Smith
# 5                        http://fr.dbpedia.org/resource/Aimé_Forest
# 6                          http://fr.dbpedia.org/resource/Al-Fârâbî
# 7                         http://fr.dbpedia.org/resource/Al-Ghazali
# 8                 http://fr.dbpedia.org/resource/Alain_(philosophe)
# 9                      http://fr.dbpedia.org/resource/Alfred_Tarski

# %% [markdown]
# # Exercice 1 : Requêtes réparties entre les 2 sources BNF et DBPedia

# %% [markdown]
# ### J1: Jointure A3 avec D2 par boucles imbriquées
# Proposer une solution pour calculer la jointure entre A3 sur le site BNF et D2 sur le site DBPedia.
# Pour chaque livre de afficher son titre et son année, le nom de l'auteur, sa nationalité et la liste de ses idées remarquables.

# %%
# fonction inspiré d'un collègue dans la salle TME
def extract_value(string):
    start = string.find("'") + 1
    end = string.rfind("'")
    return string[start:end]

# %%
from tabulate import tabulate

resultats_fin = []
# Requête A3 sur le site BNF
requete_A3 = BNF_prefix + """
SELECT distinct ?titre ?nom ?auteurDbpedia ?type_ouvrage
WHERE {
  # ?livre dc:creator ?auteur .
  # ?livre dc:title ?titre .
  # ?livre owl:sameAs ?livreWiki .
  # ?livre dc:language <http://id.loc.gov/vocabulary/iso639-2/fre> .
  # ?livre bnf:subject "Philosophie" .
  # ?auteur foaf:name ?nom .
  # ?auteur owl:sameAs ?auteurDbpedia .
  FILTER ( regex(?livreWiki, "http://wikidata.org")
       &&  regex(?auteurDbpedia, "http://fr.dbpedia.org")
  )
}
ORDER BY ?auteurDbpedia
"""

BNF.setQuery(requete_A3)
resultats_A3 = BNF.query().bindings

cpt=0   #limit = 10

# On applique la méthode des boucles imbriquées pour chaque tuple de la requête A3
for resultat_A3 in resultats_A3:

    if (cpt == 10) :
      break

    # Extraire le nom de l'auteur
    nom_auteur = extract_value(str(resultat_A3['nom'])) 
    titre_livre = extract_value(str(resultat_A3['titre']))

    # Requête D2 sur le site DBPedia
    requete_D2 = DBPEDIA_prefix + """
    SELECT distinct ?name ?nationalite ?interet ?idee
    WHERE {
      # ?pers rdf:type dbo:Person .
      # ?pers foaf:name ?name
      optional {?pers dbp:nationalité ?nationalite}
      optional {?pers dbo:mainInterest ?interet}
      optional {?pers dbp:idéesRemarquables ?idee}
      FILTER(regex(?name, "{NOM}", "i"))
    }
    order by ?interet ?idee
    """
    requete = requete_D2.replace("{NOM}", nom_auteur)

    DBPEDIA.setQuery(requete)
    resultats_D2 = DBPEDIA.query().bindings

    # Afficher le résultat
    for resultat_D2 in resultats_D2:
      if (cpt == 10) :
        break

      cpt = cpt + 1
      nationalite = extract_value(str(resultat_D2.get('nationalite', 'Inconnue')))
      interet = extract_value(str(resultat_D2.get('interet', 'Inconnue')))
      idee = extract_value(str(resultat_D2.get('idee', 'Inconnue')))

      resultats_fin.append({titre_livre, nom_auteur, nationalite, idee, interet})
      

entetes = ["Titre du livre", "Nom de l'auteur", "Nationalité", "Idée remarquable", "Intérêt"]
print(tabulate(resultats_fin, headers=entetes))
# Out:
# Titre du livre               Nom de l'auteur                                       Nationalité                               Idée remarquable    Intérêt
# ---------------------------  ----------------------------------------------------  ----------------------------------------  ------------------  ----------------------------------------------------------
# Les aventures de la liberté  Bernard-Henri Lévy                                    Inconnu
#                              http://fr.dbpedia.org/resource/Nationalité_française  Inconnu                                   Claude Guillon
#                              http://fr.dbpedia.org/resource/Histoire               Emmanuel Levinas                          Inconnu             Totalité et infini
#                              Emmanuel Levinas                                      http://fr.dbpedia.org/resource/Religion   Inconnu             Totalité et infini
#                              Emmanuel Levinas                                      http://fr.dbpedia.org/resource/Théologie  Inconnu             Totalité et infini
#                              Emmanuel Levinas                                      Inconnu                                   Totalité et infini  http://fr.dbpedia.org/resource/Érotisme
#                              Emmanuel Levinas                                      http://fr.dbpedia.org/resource/Éthique    Inconnu             Totalité et infini
# Gottfried Wilhelm Leibniz    http://fr.dbpedia.org/resource/Bibliothéconomie       Allemand                                  Monadologie         http://fr.dbpedia.org/resource/Calcul_infinitésimal
# Gottfried Wilhelm Leibniz    http://fr.dbpedia.org/resource/Bibliothéconomie       Allemand                                  Monadologie         http://fr.dbpedia.org/resource/Caractéristique_universelle
# Gottfried Wilhelm Leibniz    http://fr.dbpedia.org/resource/Bibliothéconomie       Allemand                                  Monadologie         http://fr.dbpedia.org/resource/Compatibilisme

# %% [markdown]
# ### J2 : Pour une année N afficher la liste des personnes qui sont nées l'année N et qui existent à la fois dans la BNF et dans DBPedia.
# Proposer une solution par fusion de deux résultats triés

# %%
# A compléter
annee = 1923

req1 = (
    BNF_prefix
    + """
SELECT distinct ?nom ?auteurDbpedia ?naissance
WHERE {
# ?auteur foaf:name ?nom ; bio:birth ?naissance .
# ?auteur owl:sameAs ?auteurDbpedia .
FILTER (regex(?auteurDbpedia, "http://fr.dbpedia.org")
        && xsd:integer(?naissance) = '{ANNEE}'^^xsd:integer )
}
ORDER BY desc(?naissance)
LIMIT 1000
"""
)

BNF.setQuery(req1.replace("{ANNEE}", str(annee)))
res1 = BNF.query().bindings
df1 = pd.DataFrame(res1).map(lambda x: x.value)

afficherResultat(res1)
# Out:
# 123 éléments
# schéma:  ['nom', 'auteurDbpedia', 'naissance']
#                            nom  \
# 0   Robert de La Rochefoucauld
# 1                Paul Cuvelier
# 2                  Jean Deprun
# 3              Denise Levertov
# 4                  Meng-Hua Ho
# ..                         ...
# 95               Renato Polese
# 96             Martha Schlamme
# 97                Seydou Keita
# 98                 Jean Darnel
# 99               Jean Bousquet
#
#                                                          auteurDbpedia  \
# 0            http://fr.dbpedia.org/resource/Robert_de_La_Rochefoucauld
# 1                         http://fr.dbpedia.org/resource/Paul_Cuvelier
# 2                           http://fr.dbpedia.org/resource/Jean_Deprun
# 3                       http://fr.dbpedia.org/resource/Denise_Levertov
# 4                           http://fr.dbpedia.org/resource/Ho_Meng-hua
# ..                                                                 ...
# 95                        http://fr.dbpedia.org/resource/Renato_Polese
# 96                      http://fr.dbpedia.org/resource/Martha_Schlamme
# 97  http://fr.dbpedia.org/resource/Seydou_Ke%C3%AFta_%28photographe%29
# 98                          http://fr.dbpedia.org/resource/Jean_Darnel
# 99           http://fr.dbpedia.org/resource/Jean_Bousquet_%28acteur%29
#
#    naissance
# 0       1923
# 1       1923
# 2       1923
# 3       1923
# 4       1923
# ..       ...
# 95      1923
# 96      1923
# 97      1923
# 98      1923
# 99      1923
#
# [100 rows x 3 columns]

# %%
req2 = (
    DBPEDIA_prefix
    + """
  SELECT distinct ?p year(xsd:dateTime(?naissance)) as ?naissance
  WHERE { 
    # ?p a dbo:Person .
    # ?p dbo:birthDate ?naissance
    FILTER ( regex (?naissance, '{ANNEE}') )
  }
  ORDER BY desc(?naissance)
  LIMIT 10000
"""
)

DBPEDIA.setQuery(req2.replace("{ANNEE}", str(annee)))
res2 = DBPEDIA.query().bindings
df2 = pd.DataFrame(res2).map(lambda x: x.value)

afficherResultat(res2)
# Out:
# 1437 éléments
# schéma:  ['p', 'naissance']
#                                                                          p  \
# 0                        http://fr.dbpedia.org/resource/Ștefan_Stănculescu
# 1                               http://fr.dbpedia.org/resource/Aage_Larsen
# 2                          http://fr.dbpedia.org/resource/Aaron_Antonovsky
# 3                     http://fr.dbpedia.org/resource/Abdelaziz_Benabdallah
# 4                        http://fr.dbpedia.org/resource/Abdelaziz_Bouraoui
# ..                                                                     ...
# 95                 http://fr.dbpedia.org/resource/Anne_Shelton_(chanteuse)
# 96                    http://fr.dbpedia.org/resource/Anne_de_Bourbon-Parme
# 97                            http://fr.dbpedia.org/resource/Antal_Bánkúti
# 98                http://fr.dbpedia.org/resource/Anthony_Joseph_Bevilacqua
# 99  http://fr.dbpedia.org/resource/Anthony_Noel_(5e_comte_de_Gainsborough)
#
#    naissance
# 0       1923
# 1       1923
# 2       1923
# 3       1923
# 4       1923
# ..       ...
# 95      1923
# 96      1923
# 97      1923
# 98      1923
# 99      1923
#
# [100 rows x 2 columns]

# %%
df1.merge(df2, left_on="auteurDbpedia", right_on="p")
# Out:
#                           nom  \
# 0               Paul Cuvelier
# 1             Denise Levertov
# 2                 Meng-Hua Ho
# 3               Robert Soulat
# 4          Cyril M. Kornbluth
# 5                Simon Eisner
# 6               Kildare Dobbs
# 7               Richard Wyler
# 8             Piera Aulagnier
# 9    Urbano Tavares Rodrigues
# 10  Rasul Gamzatovič Gamzatov
# 11           Yervant Gobelyan
# 12         Herbert John Ryser
# 13          Philippe Paumelle
# 14               Édith Reffet
# 15             Pierre Courcel
# 16              Pierre Naudin
# 17              Jean Clavreul
# 18    Michela Schiff Giorgini
# 19             Plinio Martini
# 20           Bruno Paolinelli
# 21            Martha Schlamme
# 22               Ana Mariscal
# 23         Patrick J. Hillery
# 24         ʿĀṣī al- Raḥbānī
#
#                                               auteurDbpedia naissance_x  \
# 0              http://fr.dbpedia.org/resource/Paul_Cuvelier        1923
# 1            http://fr.dbpedia.org/resource/Denise_Levertov        1923
# 2                http://fr.dbpedia.org/resource/Ho_Meng-hua        1923
# 3              http://fr.dbpedia.org/resource/Robert_Soulat        1923
# 4         http://fr.dbpedia.org/resource/Cyril_M._Kornbluth        1923
# 5         http://fr.dbpedia.org/resource/Cyril_M._Kornbluth        1923
# 6              http://fr.dbpedia.org/resource/Kildare_Dobbs        1923
# 7            http://fr.dbpedia.org/resource/Richard_Stapley        1923
# 8            http://fr.dbpedia.org/resource/Piera_Aulagnier        1923
# 9   http://fr.dbpedia.org/resource/Urbano_Tavares_Rodrigues        1923
# 10          http://fr.dbpedia.org/resource/Rassoul_Gamzatov        1923
# 11          http://fr.dbpedia.org/resource/Yervant_Gobelyan        1923
# 12        http://fr.dbpedia.org/resource/Herbert_John_Ryser        1923
# 13         http://fr.dbpedia.org/resource/Philippe_Paumelle        1923
# 14              http://fr.dbpedia.org/resource/Edith_Reffet        1923
# 15            http://fr.dbpedia.org/resource/Pierre_Courcel        1923
# 16             http://fr.dbpedia.org/resource/Pierre_Naudin        1923
# 17             http://fr.dbpedia.org/resource/Jean_Clavreul        1923
# 18   http://fr.dbpedia.org/resource/Michela_Schiff_Giorgini        1923
# 19            http://fr.dbpedia.org/resource/Plinio_Martini        1923
# 20          http://fr.dbpedia.org/resource/Bruno_Paolinelli        1923
# 21           http://fr.dbpedia.org/resource/Martha_Schlamme        1923
# 22              http://fr.dbpedia.org/resource/Ana_Mariscal        1923
# 23           http://fr.dbpedia.org/resource/Patrick_Hillery        1923
# 24              http://fr.dbpedia.org/resource/Assy_Rahbani        1923
#
#                                                           p naissance_y
# 0              http://fr.dbpedia.org/resource/Paul_Cuvelier        1923
# 1            http://fr.dbpedia.org/resource/Denise_Levertov        1923
# 2                http://fr.dbpedia.org/resource/Ho_Meng-hua        1923
# 3              http://fr.dbpedia.org/resource/Robert_Soulat        1923
# 4         http://fr.dbpedia.org/resource/Cyril_M._Kornbluth        1923
# 5         http://fr.dbpedia.org/resource/Cyril_M._Kornbluth        1923
# 6              http://fr.dbpedia.org/resource/Kildare_Dobbs        1923
# 7            http://fr.dbpedia.org/resource/Richard_Stapley        1923
# 8            http://fr.dbpedia.org/resource/Piera_Aulagnier        1923
# 9   http://fr.dbpedia.org/resource/Urbano_Tavares_Rodrigues        1923
# 10          http://fr.dbpedia.org/resource/Rassoul_Gamzatov        1923
# 11          http://fr.dbpedia.org/resource/Yervant_Gobelyan        1923
# 12        http://fr.dbpedia.org/resource/Herbert_John_Ryser        1923
# 13         http://fr.dbpedia.org/resource/Philippe_Paumelle        1923
# 14              http://fr.dbpedia.org/resource/Edith_Reffet        1923
# 15            http://fr.dbpedia.org/resource/Pierre_Courcel        1923
# 16             http://fr.dbpedia.org/resource/Pierre_Naudin        1923
# 17             http://fr.dbpedia.org/resource/Jean_Clavreul        1923
# 18   http://fr.dbpedia.org/resource/Michela_Schiff_Giorgini        1923
# 19            http://fr.dbpedia.org/resource/Plinio_Martini        1923
# 20          http://fr.dbpedia.org/resource/Bruno_Paolinelli        1923
# 21           http://fr.dbpedia.org/resource/Martha_Schlamme        1923
# 22              http://fr.dbpedia.org/resource/Ana_Mariscal        1923
# 23           http://fr.dbpedia.org/resource/Patrick_Hillery        1923
# 24              http://fr.dbpedia.org/resource/Assy_Rahbani        1923

# %% [markdown]
# ### J3 : Quels sont les auteurs d'une oeuvre dont le thème est philosophie (dans la BNF) et qui sont référencés comme étant des philosophes dans DBpedia ?

# %%
# A compléter

# %% [markdown]
# # Exercice 2 : Accès aux données par des requêtes de sélections
# L'objectif de cet exercice est d'appréhender la situation où l'accès aux données est contraint (voir la notion de [linked data fragment](https://linkeddatafragments.org/concept/)). Le point d'accès n'autorise que des requêtes simples (donc peut coûteuses à traiter) qui ne contiennent que des **sélections**. La clause where d'une requête ne peut contenir qu'**un seul** motif ayant 1 ou 2 variables. Les motifs autorisés sont donc parmi :
# *   ?a *propriété* ?b *(cette requête a deux variables)*
# *   *A* *propriété* ?b  *(cette requête a une seule variable)*
# *   ?a *propriété* *B*
#
# où ?a et ?b sont des variables et *A*, *B* et *propriété* sont des valeurs fixées avant de poser la requête.
#
# Ainsi, toutes les jointures doivent être exprimées par le client qui accède aux données : vous devez "programmer" toutes les jointures en python.
# Pour les requêtes D1 et D6 proposer une solution respectant ce mode d'accès.

# %%
# pip install tabulate

# %%
# # à compléter
# from SPARQLWrapper import SPARQLWrapper, JSON
# from tabulate import tabulate
# # Définir l'URL du point d'accès DBpedia
# DBPEDIA_prefix = "http://dbpedia.org/sparql"

# # Définir l'objet SPARQLWrapper pour le point d'accès DBpedia
# DBPEDIA = SPARQLWrapper(DBPEDIA_prefix)
# DBPEDIA.setReturnFormat(JSON)

# # Fonction pour effectuer une requête simple et récupérer les résultats
# def effectuer_requete(requete):
#     DBPEDIA.setQuery(requete)
#     res = DBPEDIA.query().convert()
#     return res['results']['bindings']

# # Requête principale pour récupérer les informations de base sur les personnes
# requete_principale = """
# SELECT ?p ?name ?naissance
# WHERE {
#   ?p a dbo:Person .
#   ?p foaf:name ?name .
#   ?p dbo:birthDate ?naissance
#   FILTER (regex(?name, "{MOTIF}", "i"))
# }
# LIMIT 10
# """

# # Remplacer le motif dans la requête principale
# motif = "Victor.*Hug"
# requete_principale = requete_principale.replace("{MOTIF}", motif)

# # Effectuer la requête principale en utilisant la fonction effectuer_requete
# resultats_principaux = effectuer_requete(requete_principale)

# # Liste pour stocker les résultats complets
# resultats_complets = []

# # Parcourir les résultats principaux pour récupérer les informations supplémentaires
# for resultat in resultats_principaux:
#     personne = {
#         'p': resultat['p']['value'],
#         'name': resultat['name']['value'],
#         'naissance': resultat['naissance']['value']
#     }
    
#     # Requêtes supplémentaires pour récupérer la nationalité, la profession et le lieu de naissance
#     requete_nationalite = f"""
#     SELECT ?nationalité WHERE {{
#       <{personne['p']}> dbp:nationalité ?nationalité
#     }}
#     """
#     requete_profession = f"""
#     SELECT ?profession WHERE {{
#       <{personne['p']}> dbp:profession ?profession
#     }}
#     """
#     requete_lieu_naissance = f"""
#     SELECT ?lieu WHERE {{
#       <{personne['p']}> dbp:lieuDeNaissance ?lieu
#     }}
#     """
    
#     # Exécuter les requêtes supplémentaires et ajouter les informations au dictionnaire de la personne
#     nationalite = effectuer_requete(requete_nationalite)
#     profession = effectuer_requete(requete_profession)
#     lieu_naissance = effectuer_requete(requete_lieu_naissance)
    
#     if nationalite:
#         personne['nationalité'] = nationalite[0]['nationalité']['value']
#     else:
#         personne['nationalité'] = None
        
#     if profession:
#         personne['profession'] = profession[0]['profession']['value']
#     else:
#         personne['profession'] = None
        
#     if lieu_naissance:
#         personne['lieu'] = lieu_naissance[0]['lieu']['value']
#     else:
#         personne['lieu'] = None
        
#     resultats_complets.append(personne)

# # Afficher les résultats complets sous forme tabulaire
# print(tabulate(resultats_complets, headers="keys", tablefmt="grid"))

# %% [markdown]
# # Exercice 3 : Accès par morceau au résultat d'une requête
# 1) Un utilisateur veut accéder aux données de manière progressive. Proposer une solution pour obtenir le resultat d'une requete par morceau de N tuples, en utilisant les mots-clés OFFSET et LIMIT. Appliquer cela pour lire le résultat de la requête qui affiche le nom des personnes existant dans dbpedia.
# Etudier l'influence de l'offset et de la taille du résultat sur le temps de réponse de la requête.

# %%
# Exemple d'utilisation de OFFSET et LIMIT

# Compléter cet exemple


import time
offset = 1  
limit = 10
requete = DBPEDIA_prefix + f"""
SELECT distinct ?p ?name
WHERE {{
  # ?p rdf:type dbo:Person .
  # ?p foaf:name ?name
  FILTER(  STRLEN(?name) != 0)
}}
OFFSET {offset} LIMIT {limit}
"""

start_time = time.time()
# exécution de la requête
DBPEDIA.setQuery(requete)
res = DBPEDIA.query().bindings
duree = int ( (time.time() - start_time) * 1000)
print(f"la requête dure {duree} ms")

afficherResultat(res)
# Out:
# la requête dure 20 ms
# 10 éléments
# schéma:  ['p', 'name']
#                                                   p               name
# 0      http://fr.dbpedia.org/resource/Łukasz_Gibała      Łukasz Gibała
# 1      http://fr.dbpedia.org/resource/Łukasz_Gierak             Gierak
# 2  http://fr.dbpedia.org/resource/Łukasz_Grzeszczuk  Łukasz Grzeszczuk
# 3   http://fr.dbpedia.org/resource/Łukasz_Kaczmarek   Łukasz Kaczmarek
# 4      http://fr.dbpedia.org/resource/Łukasz_Klekot      Łukasz Klekot
# 5       http://fr.dbpedia.org/resource/Łukasz_Kohut       Łukasz Kohut
# 6    http://fr.dbpedia.org/resource/Łukasz_Koszarek    Łukasz Koszarek
# 7   http://fr.dbpedia.org/resource/Łukasz_Krupiński   Łukasz Krupiński
# 8       http://fr.dbpedia.org/resource/Łukasz_Kubot       Łukasz Kubot
# 9   http://fr.dbpedia.org/resource/Łukasz_Michalski   Łukasz Michalski

# %%
import time

# Définition de la requête SPARQL avec OFFSET et LIMIT
offset = 1  
limit = 10
requete = DBPEDIA_prefix + f"""
SELECT distinct ?p ?name
WHERE {{
  # ?p rdf:type dbo:Person .
  # ?p foaf:name ?name
  FILTER(STRLEN(?name) != 0)
}}
OFFSET {offset} LIMIT {limit}
"""

# Paramètres pour contrôler le nombre de tuples récupérés à chaque étape
OFFSET = 0  # Début à partir de la première ligne
LIMIT = 10  # Nombre de tuples à récupérer à chaque étape

start_time = time.time()

# Boucle pour lire les données progressivement
while True:
    # Modification de la requête avec les valeurs d'OFFSET et de LIMIT
    requete_modifiee = requete.replace("{OFFSET}", str(OFFSET)).replace("{LIMIT}", str(LIMIT))

    # Exécution de la requête
    DBPEDIA.setQuery(requete_modifiee)
    res = DBPEDIA.query().bindings
    
    # Affichage des résultats
    afficherResultat(res)
    
    # Vérification s'il y a plus de données à récupérer
    if len(res) < LIMIT:
        break
    
    # Mise à jour de l'OFFSET pour la prochaine itération
    OFFSET += LIMIT

# Calcul de la durée totale d'exécution de la requête
duree = int((time.time() - start_time) * 1000)
print(f"La requête a duré {duree} ms")

# %% [markdown]
# 2) Définir une fonction traiteRequete(requete) qui retourne un generateur sur une requete de telle sorte que la requete soit lue par morceaux de N tuples et que seuls les morceaux permettant de produire les M lignes demandées par l'utlisateur soit lus. On ne connait pas à l'avance le nombre M de lignes que va lire l'utilisateur. On a M > N.
# Indication voir le mot clé python **yield** pour retourner un générateur.

# %%
requete = DBPEDIA_prefix + """
SELECT distinct ?name ?p
WHERE {
  # ?p rdf:type dbo:Person .
  # ?p foaf:name ?name
  FILTER(  STRLEN(?name) != 0)
}
"""

# définition d'un générateur
def traiteRequete(requete):
  offset = 0
  total_read = 0
  limit = 10
  while True:
      # Update the query with the current offset
      query = requete + f" OFFSET {offset} LIMIT {limit}"
      
      # Execute the query
      DBPEDIA.setQuery(query)
      results = DBPEDIA.query().bindings
      result_count = len(results)
      print(f"Read {result_count} results")        
      # Yield each result
      for r in results:
          yield r

      offset = offset + limit        
      # If fewer results were returned than the limit, no need to continue
      if result_count < limit:
          break
        

# Nombre de tuples que l'utilisateur souhaite lire
a_lire = 20

lu = 0
for a in traiteRequete(requete):
  print(a)
  lu += 1
  if(lu >= a_lire):
    break

print()
if(lu < a_lire):
  print(f"Attention !!!! l'utilisateur n'a obtenu que {lu} lignes sur les {a_lire}")
else:
  print(f"OK, l'utilisateur a obtenu {lu} lignes sur les {a_lire}")
# Out:
# Read 10 results
# {'name': Value(literal:'Łukasz Bujko'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Bujko')}
# {'name': Value(literal:'Łukasz Gibała'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Gibała')}
# {'name': Value(literal:'Gierak'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Gierak')}
# {'name': Value(literal:'Łukasz Grzeszczuk'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Grzeszczuk')}
# {'name': Value(literal:'Łukasz Kaczmarek'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Kaczmarek')}
# {'name': Value(literal:'Łukasz Klekot'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Klekot')}
# {'name': Value(literal:'Łukasz Kohut'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Kohut')}
# {'name': Value(literal:'Łukasz Koszarek'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Koszarek')}
# {'name': Value(literal:'Łukasz Krupiński'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Krupiński')}
# {'name': Value(literal:'Łukasz Kubot'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Kubot')}
# Read 10 results
# {'name': Value(literal:'Łukasz Michalski'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Michalski')}
# {'name': Value(literal:'Łukasz Palkowski'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Palkowski')}
# {'name': Value(literal:'Łukasz Pawłowski'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Pawłowski')}
# {'name': Value(literal:'Łukasz Pryga'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Pryga')}
# {'name': Value(literal:'Łukasz Przybytek'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Przybytek')}
# {'name': Value(literal:'Łukasz Rudzewicz'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Rudzewicz')}
# {'name': Value(literal:'Lukasz Rutkowski'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Rutkowski')}
# {'name': Value(literal:'Łukasz Siemion'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Siemion')}
# {'name': Value(literal:'Łukasz Simlat'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Simlat')}
# {'name': Value(literal:'Łukasz Szczurek'), 'p': Value(uri:'http://fr.dbpedia.org/resource/Łukasz_Szczurek')}
#
# OK, l'utilisateur a obtenu 20 lignes sur les 20

# %% [markdown]
# 3) Proposer une solution pour accéder de manière progressive au résultat d'une requête de jointure entre 2 sites, par exemple J1.

# %%
from tabulate import tabulate

requete_bnf = BNF_prefix + """
SELECT distinct ?titre ?nom ?auteurDbpedia ?type_ouvrage
WHERE {
  # ?livre dc:creator ?auteur .
  # ?livre dc:title ?titre .
  # ?livre owl:sameAs ?livreWiki .
  # ?livre dc:language <http://id.loc.gov/vocabulary/iso639-2/fre> .
  # ?livre bnf:subject "Philosophie" .
  # ?auteur foaf:name ?nom .
  # ?auteur owl:sameAs ?auteurDbpedia .
  FILTER ( regex(?livreWiki, "http://wikidata.org")
       &&  regex(?auteurDbpedia, "http://fr.dbpedia.org")
  )
}
ORDER BY ?auteurDbpedia
"""

requete_dbpedia = DBPEDIA_prefix + """
SELECT DISTINCT ?name ?nationalite ?interet ?idee
WHERE {
  # ?pers a dbo:Person .
  # ?pers foaf:name ?name.
  OPTIONAL { ?pers dbp:nationalité ?nationalite }
  OPTIONAL { ?pers dbo:mainInterest ?interet }
  OPTIONAL { ?pers dbp:idéesRemarquables ?idee }
  FILTER(regex(?name, "{NOM}", "i"))
}
ORDER BY ?interet ?idee
"""

def site_bnf():
    BNF.setQuery(requete_bnf)
    resultats_bnf = BNF.query().bindings
    for resultat in resultats_bnf:
        yield resultat

def site_DBPedia(name):
    requete = requete_dbpedia.replace("{NOM}", name)
    DBPEDIA.setQuery(requete)
    resultats_dbpedia = DBPEDIA.query().bindings
    for resultat in resultats_dbpedia:
        yield resultat

# combiner progressivement les résultats des deux sites
def acces_progressive(limit):
    for resultat_bnf in site_bnf():
        if limit == 0: # safe condition
            break

        # site BNF
        nom_auteur = extract_value(str(resultat_bnf['nom']))
        titre_livre = extract_value(str(resultat_bnf['titre']))

        # Site DBPedia
        for resultat_dbpedia in site_DBPedia(nom_auteur):
            if limit == 0:
                break

            nationalite = extract_value(str(resultat_dbpedia.get('nationalite', 'Inconnue')))
            interet = extract_value(str(resultat_dbpedia.get('interet', 'Inconnue')))
            idee = extract_value(str(resultat_dbpedia.get('idee', 'Inconnue')))

            limit = limit - 1

            # Jointure des données
            yield {
                'titre_livre': titre_livre,
                'nom_auteur': nom_auteur,
                'nationalite': nationalite,
                'interet': interet,
                'idee': idee
            }

# Entêtes de colonnes
entetes = ["Titre du livre", "Nom de l'auteur", "Nationalité", "Intérêt", "Idée remarquable"]

# Fonction pour afficher les résultats progressivement
def afficher_resultats_progressivement(limit):
    # Utiliser la fonction pour afficher les résultats progressivement
    for resultat_joint in acces_progressive(limit):
        print(tabulate([[resultat_joint['titre_livre'],
                         resultat_joint['nom_auteur'],
                         resultat_joint['nationalite'],
                         resultat_joint['interet'],
                         resultat_joint['idee']]], headers=entetes))
        print()  # Ajouter une ligne vide entre chaque résultat

# Afficher les résultats progressivement avec une limite de 10 résultats
afficher_resultats_progressivement(10)
# Out:
# Titre du livre               Nom de l'auteur     Nationalité    Intérêt    Idée remarquable
# ---------------------------  ------------------  -------------  ---------  ------------------
# Les aventures de la liberté  Bernard-Henri Lévy  Inconnu        Inconnu    Inconnu
#
# Titre du livre    Nom de l'auteur    Nationalité                                           Intérêt    Idée remarquable
# ----------------  -----------------  ----------------------------------------------------  ---------  ------------------
#                   Claude Guillon     http://fr.dbpedia.org/resource/Nationalité_française  Inconnu    Inconnu
#
# Titre du livre      Nom de l'auteur    Nationalité    Intérêt                                  Idée remarquable
# ------------------  -----------------  -------------  ---------------------------------------  ------------------
# Totalité et infini  Emmanuel Levinas   Inconnu        http://fr.dbpedia.org/resource/Histoire
#
# Titre du livre      Nom de l'auteur    Nationalité    Intérêt                                  Idée remarquable
# ------------------  -----------------  -------------  ---------------------------------------  ------------------
# Totalité et infini  Emmanuel Levinas   Inconnu        http://fr.dbpedia.org/resource/Religion
#
# Titre du livre      Nom de l'auteur    Nationalité    Intérêt                                   Idée remarquable
# ------------------  -----------------  -------------  ----------------------------------------  ------------------
# Totalité et infini  Emmanuel Levinas   Inconnu        http://fr.dbpedia.org/resource/Théologie
#
# Titre du livre      Nom de l'auteur    Nationalité    Intérêt                                  Idée remarquable
# ------------------  -----------------  -------------  ---------------------------------------  ------------------
# Totalité et infini  Emmanuel Levinas   Inconnu        http://fr.dbpedia.org/resource/Érotisme
#
# Titre du livre      Nom de l'auteur    Nationalité    Intérêt                                 Idée remarquable
# ------------------  -----------------  -------------  --------------------------------------  ------------------
# Totalité et infini  Emmanuel Levinas   Inconnu        http://fr.dbpedia.org/resource/Éthique
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  ---------------------------------------------------
# Monadologie       Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Calcul_infinitésimal
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  ----------------------------------------------------------
# Monadologie       Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Caractéristique_universelle
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  ---------------------------------------------
# Monadologie       Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Compatibilisme

# %% [markdown]
# -----------------------------------------------------------------------------
# ## Explication:
#
# Dans ce code, j'ai mis en place un mécanisme de requête de jointure entre deux sites, la Bibliothèque nationale de France (BNF) et DBPedia, pour obtenir des informations sur des livres et leurs auteurs.
#
# Tout d'abord, j'ai défini deux requêtes SPARQL, une pour interroger la BNF et une autre pour interroger DBPedia. Ces requêtes récupèrent respectivement les titres des livres, les noms des auteurs, et d'autres informations pertinentes comme la nationalité, les intérêts et les idées remarquables des auteurs.
#
# Ensuite, j'ai créé des fonctions pour exécuter progressivement ces requêtes sur chaque site. La fonction `site_bnf()` interroge la BNF pour obtenir les détails des livres et des auteurs, tandis que `site_DBPedia()` interroge DBPedia pour obtenir des informations supplémentaires sur les auteurs en utilisant leur nom. Ces fonctions renvoient les résultats de manière itérative grâce à l'utilisation de générateurs.
#
# J'ai également défini une fonction `acces_progressive()` qui combine les résultats des deux sites progressivement. Elle exécute d'abord la requête sur la BNF, puis pour chaque résultat, exécute la requête correspondante sur DBPedia pour obtenir des informations détaillées sur l'auteur. Les résultats sont combinés et renvoyés un par un.
#
# Enfin, j'ai mis en place une fonction `afficher_resultats_progressivement()` qui affiche les résultats *progressivement* à mesure qu'ils sont obtenus. Cette fonction utilise la fonction de jointure progressive avec une limite sur le nombre de résultats à afficher, et utilise la bibliothèque tabulate pour présenter les résultats sous forme de tableau avec des en-têtes de colonnes. Cette approche permet de gérer efficacement de grandes quantités de données tout en fournissant des résultats de manière progressive pour une meilleure lisibilité et une utilisation plus efficace des ressources.
#
# -----------------------------------------------------------------------------

# %% [markdown]
# # Exerice 4 : Cache de requêtes
# 1) Proposer des améliorations des requêtes précédentes afin d'éviter de poser plusieurs fois une même requête. On suppose que le résultat de la requête ne change pas entre deux invocations de la même requête.
#
# 2) Cache avec une capacité limitée : considérer qu'on peut conserver en cache le résultat de C requêtes (C=10) au maximum

# %%
# Pour éviter de poser plusieurs fois la même requête, nous pouvons mettre en place un système de cache 
# pour stocker les résultats des requêtes précédentes. Lorsqu'une requête est exécutée, nous vérifions 
# d'abord si les résultats sont déjà présents dans le cache. Si c'est le cas, nous les récupérons
#  à partir du cache plutôt que de poser à nouveau la requête.
from tabulate import tabulate

# Déclaration du cache
cache_bnf = {}
cache_dbpedia = {}

def site_bnf():
    if not cache_bnf:
        BNF.setQuery(requete_bnf)
        resultats_bnf = BNF.query().bindings
        cache_bnf.update({nom_auteur: resultat for resultat in resultats_bnf})
    return cache_bnf.items()

def site_DBPedia(name):
    if name not in cache_dbpedia:
        requete = requete_dbpedia.replace("{NOM}", name)
        DBPEDIA.setQuery(requete)
        resultats_dbpedia = DBPEDIA.query().bindings
        cache_dbpedia[name] = resultats_dbpedia
    return cache_dbpedia[name]

# combiner progressivement les résultats des deux sites
def acces_progressive(limit):
    for nom_auteur, resultat_bnf in site_bnf():
        if limit == 0: # safe condition
            break

        # site BNF
        titre_livre = extract_value(str(resultat_bnf['titre']))

        # Site DBPedia
        for resultat_dbpedia in site_DBPedia(nom_auteur):
            if limit == 0:
                break

            nationalite = extract_value(str(resultat_dbpedia.get('nationalite', 'Inconnue')))
            interet = extract_value(str(resultat_dbpedia.get('interet', 'Inconnue')))
            idee = extract_value(str(resultat_dbpedia.get('idee', 'Inconnue')))

            limit = limit - 1

            # Jointure des données
            yield {
                'titre_livre': titre_livre,
                'nom_auteur': nom_auteur,
                'nationalite': nationalite,
                'interet': interet,
                'idee': idee
            }

# Entêtes de colonnes
entetes = ["Titre du livre", "Nom de l'auteur", "Nationalité", "Intérêt", "Idée remarquable"]

# Fonction pour afficher les résultats progressivement
def afficher_resultats_progressivement(limit):
    # Utiliser la fonction pour afficher les résultats progressivement
    for resultat_joint in acces_progressive(limit):
        print(tabulate([[resultat_joint['titre_livre'],
                         resultat_joint['nom_auteur'],
                         resultat_joint['nationalite'],
                         resultat_joint['interet'],
                         resultat_joint['idee']]], headers=entetes))
        print()  # Ajouter une ligne vide entre chaque résultat

# Afficher les résultats progressivement avec une limite de 10 résultats
afficher_resultats_progressivement(10)
# Out:
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  ---------------------------------------------------
# Cahiers           Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Calcul_infinitésimal
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  ----------------------------------------------------------
# Cahiers           Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Caractéristique_universelle
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  ---------------------------------------------
# Cahiers           Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Compatibilisme
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  --------------------------------------------------
# Cahiers           Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Harmonie_préétablie
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  ------------------------------------------------------------
# Cahiers           Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Meilleur_des_mondes_possibles
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  ---------------------------------------------------
# Cahiers           Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Monade_(philosophie)
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  --------------------------------------------------
# Cahiers           Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Notation_de_Leibniz
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  ------------------
# Cahiers           Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  -----------------------------------------------------
# Cahiers           Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Principe_de_continuité
#
# Titre du livre    Nom de l'auteur            Nationalité    Intérêt                                          Idée remarquable
# ----------------  -------------------------  -------------  -----------------------------------------------  ------------------------------------------------------------
# Cahiers           Gottfried Wilhelm Leibniz  Allemand       http://fr.dbpedia.org/resource/Bibliothéconomie  http://fr.dbpedia.org/resource/Principe_de_raison_suffisante

# %% [markdown]
# # FAQ: Questions diverses

# %% [markdown]
# ## Mise au point des requêtes
# Pour débugguer et **mettre au point vos requêtes** Sparql, il est utile de les tester directement sur l'interface du point d'accès dédié de la source de données. L'avantage est que cela vous retourne un message indiquant très précisément la nature et l'endroit où se trouve l'erreur dans la requête.
# *   [BNF](http://data.bnf.fr/sparql) voir des [exemples](https://api.bnf.fr/sparql-endpoint-de-databnffr)
# *   [DBPedia](http://fr.dbpedia.org/sparql) et la liste de tous les [prefixes](http://fr.dbpedia.org/sparql?nsdecl)

# %% [markdown]
# ## Autres sources de données
# Autres sources à votre disposition pour proposer des requêtes multi-sources:
#
# 1.   [Mondial](http://www.semwebtech.org/mondial/10/sparql) : données géopolitiques. Attention le résulat des requêtes est en XML pas en JSON.
# 2.   [Persée](data.persee.fr) : données bibliographiques alignées avec plusieurs autres sources dont dbpedia. Voir des [exemples](http://data.persee.fr/ressources/requetes-exemples/)
# 3.   [BioPortal](http://sparql.bioontology.org)
# 4.    [IdRef](https://data.idref.fr/sparql) serveur d’autorité IdRef et les références bibliographiques en provenance du Sudoc.
# 5.   [Insee](https://rdf.insee.fr/sparql)
# 6.  [Geonames web services](https://www.geonames.org/export/ws-overview.html)

# %% [markdown]
# ## SPARKLIS : aide à l'écriture de requêtes Sparql
# Pour exprimer vos requêtes en *langage naturel* et les traduire automatiquement en SPARQL, voir l'appli [Sparklis](http://www.irisa.fr/LIS/ferre/sparklis/)
#
#
# *   onglet **Sparklis** pour exprimer vos requêtes en langage naturel
# *   onglet **YASGUI** pour voir la traduction en Sparql

# %% [markdown]
# ## Nombre d'éléments dans le resultat d'une requête
# Pour compter le nombre d'éléments d'une requête, utiliser la notation avec requête imbriquée dans le where :
#
# SELECT (count(1) as ?nb)
#
# WHERE { *sous-requete* }
